# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0     tanjung pandan  -2.7500  107.6500     24.46        86
# 1        1         codrington -38.2667  141.9667     13.34        71
# 2        2         gadzhiyevo  69.2551   33.3362      8.44        84
# 3        3  san andres ixtlan  19.8167 -103.4667     25.99        65
# 4        4         isafjordur  66.0755  -23.1240     10.02        62
#
#    Cloudiness  Wind Speed Country        Date
# 0          13        3.06      ID  1694629582
# 1         100        3.76      AU  1694629583
# 2          99        2.73      RU  1694629583
# 3          83        1.03      MX  1694629583
# 4           0        4.12      IS  1694629583

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    size = "Humidity",
    frame_width = 800,
    frame_height = 600    
)

# Display the map
# YOUR CODE HERE
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values 
#A max temperature lower than 27 degrees but higher than 21
#Wind speed less than 4.5 m/s
#Zero cloudiness
# YOUR CODE HERE
temp_df = city_data_df[(city_data_df['Max Temp']<=27)]
tempy_df = temp_df[(temp_df['Max Temp']>21)]
windy_df = tempy_df[(tempy_df['Wind Speed']<4.5)]
cloud_df = windy_df[(windy_df['Cloudiness']==0)]
# Drop any rows with null values
# YOUR CODE HERE
vacay_df = cloud_df.dropna(how='any',axis=0) 


# Display sample data
# YOUR CODE HERE
vacay_df
# Out:
#      City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 50        50  saint-pierre -21.3393   55.4781     21.82        68           0
# 107      107  mersa matruh  31.3525   27.2453     26.00        63           0
# 129      129     karacabey  40.2152   28.4038     21.21        71           0
# 321      321         demre  36.2537   29.9777     25.78        50           0
# 322      322      holualoa  19.6228 -155.9522     25.91        69           0
# 331      331      skiathos  39.1623   23.4909     23.32        78           0
# 392      392        shache  38.4167   77.2406     25.95        18           0
# 415      415           kas  36.2018   29.6377     25.82        52           0
# 416      416         hotan  37.0997   79.9269     25.41        19           0
# 498      498   archangelos  36.2149   28.1149     26.28        58           0
#
#      Wind Speed Country        Date
# 50         2.57      RE  1694629588
# 107        3.97      EG  1694629595
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = pd.DataFrame(vacay_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']])

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name']= ''
# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 50   saint-pierre      RE -21.3393   55.4781        68
# 107  mersa matruh      EG  31.3525   27.2453        63
# 129     karacabey      TR  40.2152   28.4038        71
# 321         demre      TR  36.2537   29.9777        50
# 322      holualoa      US  19.6228 -155.9522        69
# 331      skiathos      GR  39.1623   23.4909        78
# 392        shache      CN  38.4167   77.2406        18
# 415           kas      TR  36.2018   29.6377        52
# 416         hotan      CN  37.0997   79.9269        19
# 498   archangelos      GR  36.2149   28.1149        58

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": "accommodation.hotel",  # Search for lodging places (hotels)
    "limit": 1, 
    "apiKey": geoapify_key
}
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    latitude = row['Lat']
    longitude = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["lat"] = latitude
    params["lon"] = longitude
    params["radius"] = radius

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty

    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_name = name_address["features"][0]["properties"]["name"]
        hotel_df.loc[index, "Hotel Name"] = hotel_name
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# saint-pierre - nearest hotel: Tropic Hotel
# mersa matruh - nearest hotel: صقور
# karacabey - nearest hotel: Ün Otel
# demre - nearest hotel: hotel Kiyak
# holualoa - nearest hotel: Kona Hotel
# skiathos - nearest hotel: Pension pineapple
# shache - nearest hotel: 莎車新盛賓舘
# kas - nearest hotel: KEKOVA OTEL
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# archangelos - nearest hotel: Semina
#              City Country      Lat       Lng  Humidity  \
# 50   saint-pierre      RE -21.3393   55.4781        68
# 107  mersa matruh      EG  31.3525   27.2453        63
# 129     karacabey      TR  40.2152   28.4038        71
# 321         demre      TR  36.2537   29.9777        50
# 322      holualoa      US  19.6228 -155.9522        69
# 331      skiathos      GR  39.1623   23.4909        78
# 392        shache      CN  38.4167   77.2406        18
# 415           kas      TR  36.2018   29.6377        52
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    size = 500,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    hover_cols=['Lng','Lat','Hotel Name','Country']   
)
# Display the map
# YOUR CODE HERE
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Hotel Name,Country)

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_1.append
# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
